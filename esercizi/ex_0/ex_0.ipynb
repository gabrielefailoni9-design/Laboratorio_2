# %% [markdown]
# # Foglio Esercizi 0

# %%
import ex_0_utils as utils

# %% [markdown]
# ### Ex 1 [1.25 pt]: Scrivi una funzione che prende in input un intero n e stampa i numeri pari compresi tra 0 e n
#
# Esempio: fun(5) stampa 0, 2, 4

# %%
# Esempio
utils.fun_1(10)

# %% [markdown]
# ### Ex 2 [1.25 pt]: Scrivi una funzione che prende in input un intero n e se è dispari restituisce il doppio del suo valore, se è pari la metà
#
# Esempio: fun(3) -> 6, mentre fun(4) -> 2

# %%
# Esempio
print(utils.fun_2(10))
print(utils.fun_2(21))

# %% [markdown]
# ### Ex 3 [1.5 pt]: Scrivi una funzione che prende in input una lista di numeri interi e restituisce l'elemento più piccolo
#
# Esempio: fun([1, 3, -1, 5]) -> -1

# %%
utils.fun_3([1, 2, 3, -4, 5])

# %% [markdown]
# ### Ex 4 [1.25 pt]: Scrivi una funzione che prende in input un array e restituisce la somma degli elementi divisibili per 3 o per 5
#
# Esempio: fun([1, 3, 2, 10]) -> 13

# %%
print(utils.fun_4([1, 2, 3, -4, 5]))

# %% [markdown]
# ### Ex 5 [1.25 pt]: Scrivi una funzione che prende in input una lista di numeri e calcola la varianza
#
# $$var = \frac{\sum_{i=1}^{n}(x_i-\bar{x})^2}{n}$$
#
# dove $\bar{x}$ è la media dei valori della lista.
#
# Esempio: fun([1, 1, 1, 1, 1, 1]) -> 0, fun([1, 2, 3]) -> 0.67
#
# > Suggerimento: nella funzione prima calcola la media poi calcola la varianza e restituiscila

# %%
print(utils.fun_5([1, 1, 1, 1, 1]))
print(utils.fun_5([2, 2, 2, 0, 0, 0]))

# %% [markdown]
# ### Ex 6 [1.5 pt]: Scrivi una funzione che prende in input  un intero n e restituisce l'ennesimo termine della serie
#
# $$s(n) = \sum_{i=0}^n \frac{1}{i!}$$
#
# Memo: ! indica il fattoriale. Esempio: 4! = 4x3x2x1
#
# Prova a stampare i primi termini della serie s(0), s(1), s(2), s(3), ...
#
# I primi valori che vedi dovrebbero essere 1, 2, 2.5, 2.6667, ...
#
# Prova a stampare s(10), s(20), s(30)
#
# A che valore converge la serie? Sapresti riconoscere questo valore?
#
# > Suggerimento: Segui questo ordine
# > 1. Scrivi una funzione a parte che prende in input un intero n e calcola il fattoriale n!=n(n-1)(n-2)...1
# >   - Memo: 0! = 1, mentre per tutti gli altri numeri n!=n(n-1)(n-2)...1
# >   - Esempio: 5! = 5x4x3x2x1 = 120, 3! = 3x2x1= 6, 1! = 1
# > 2. Scrivi una seconda funzione per calcolare l'ennesimo termine della serie in cui richiami la funzione fattoriale

# %%
# Stampa il fatoriale dei numeri da 0 a 20
for i in range(21):
    print(f"{i}! = {utils.fattoriale(i)}")

# %%
# Stampa i primi 20 numeri della serie sopra indicata
for i in range(21):
    print(f"s({i}) = {utils.fun_6(i)}")
